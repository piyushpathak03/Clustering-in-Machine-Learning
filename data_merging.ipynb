# %%
import modin.pandas as pd
import numpy as np

# %%
def reduce_mem_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2    
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)    
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose: print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df

# %%
df1=pd.read_csv("olist_customers_dataset.csv")
df1 = reduce_mem_usage(df1)
df1
# Out:
# ...
# Mem. usage decreased to  3.41 Mb (10.0% reduction)
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
# ...

# %%
df1.info()
# Out:
# ...
# <class 'modin.pandas.dataframe.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------------------------  --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int32
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: object(4), int32(1)
# memory usage: 3.4 MB

# %%
df1.isnull().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
df2=pd.read_csv("olist_geolocation_dataset.csv")
df2 = reduce_mem_usage(df2)
df2
# Out:
# Mem. usage decreased to 22.89 Mb (40.0% reduction)
#          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                               1037       -23.546875        -46.62500
# 1                               1046       -23.546875        -46.65625
# 2                               1046       -23.546875        -46.65625
# 3                               1041       -23.546875        -46.62500
# 4                               1035       -23.546875        -46.65625
# ...                              ...              ...              ...
# 1000158                        99950       -28.062500        -52.00000
# 1000159                        99900       -27.875000        -52.21875
# 1000160                        99950       -28.078125        -52.00000
# 1000161                        99980       -28.390625        -51.84375
# 1000162                        99950       -28.062500        -52.03125
#
#            customer_city customer_state
# ...

# %%
df2.info()
# Out:
# <class 'modin.pandas.dataframe.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ---------------------------  ----------------  -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int32
#  1   geolocation_lat              1000163 non-null  float16
#  2   geolocation_lng              1000163 non-null  float16
#  3   customer_city                1000163 non-null  object
#  4   customer_state               1000163 non-null  object
# dtypes: float16(2), object(2), int32(1)
# memory usage: 22.9 MB
# ...

# %%
df2.isnull().sum()
# Out:
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# customer_city                  0
# customer_state                 0
# dtype: int64

# %%
df3=pd.read_csv("olist_order_items_dataset.csv")
df3 = reduce_mem_usage(df3)
df3
# Out:
# Mem. usage decreased to  3.98 Mb (33.9% reduction)
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
df3.info()
# Out:
# ...
# <class 'modin.pandas.dataframe.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  -------------------  ---------------  -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int8
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float16
#  6   freight_value        112650 non-null  float16
# dtypes: object(4), float16(2), int8(1)
# memory usage: 4.0 MB

# %%
df3.isnull().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
df4=pd.read_csv("olist_order_payments_dataset.csv")
df4 = reduce_mem_usage(df4)
df4
# Out:
# Mem. usage decreased to  1.98 Mb (50.0% reduction)
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
# ...

# %%
df4.info()
# Out:
# <class 'modin.pandas.dataframe.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  --------------------  ---------------  -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int8
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int8
#  4   payment_value         103886 non-null  float16
# dtypes: int8(2), object(2), float16(1)
# memory usage: 2.0 MB
# ...

# %%
df4.isnull().sum()
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %%
#Merging csv3 and csv4

df3_4= df3.merge(df4, on='order_id', how='left')
df3_4
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 117599  fffc94f6ce00a00581880bf54a75a037              1
# 117600  fffcd46ef2263f404302a634eb57f7eb              1
# 117601  fffce4705a9662cd70adb13d4a31832d              1
# 117602  fffe18544ffabc95dfada21779c9644f              1
# 117603  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
df3_4.isnull().sum()
# Out:
# order_id                0
# order_item_id           0
# product_id              0
# seller_id               0
# shipping_limit_date     0
# price                   0
# freight_value           0
# payment_sequential      3
# payment_type            3
# payment_installments    3
# payment_value           3
# dtype: int64

# %%
df5=pd.read_csv("olist_order_reviews_dataset.csv")
df5 = reduce_mem_usage(df5)
df5
# Out:
# ...
# Mem. usage decreased to  4.67 Mb (12.5% reduction)
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99995  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99996  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99997  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99998  be360f18f5df1e0541061c87021e6d93  f8bd3f2000c28c5342fedeb5e50f2e75
# 99999  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
# ...

# %%
df5.info()
# Out:
# ...
# <class 'modin.pandas.dataframe.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  -----------------------  ---------------  -----
#  0   review_id                100000 non-null  object
#  1   order_id                 100000 non-null  object
#  2   review_score             100000 non-null  int8
#  3   review_comment_title     11715 non-null   object
#  4   review_comment_message   41753 non-null   object
#  5   review_creation_date     100000 non-null  object
#  6   review_answer_timestamp  100000 non-null  object
# dtypes: object(6), int8(1)
# memory usage: 4.7 MB

# %%
df5.isnull().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       88285
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
#merging csv3_4 and csv 5
df3_4_5= df3_4.merge(df5, on='order_id', how='left')
df3_4_5
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 118313  fffc94f6ce00a00581880bf54a75a037              1
# 118314  fffcd46ef2263f404302a634eb57f7eb              1
# 118315  fffce4705a9662cd70adb13d4a31832d              1
# 118316  fffe18544ffabc95dfada21779c9644f              1
# 118317  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
df3_4_5.isnull().sum()
# Out:
# order_id                        0
# order_item_id                   0
# product_id                      0
# seller_id                       0
# shipping_limit_date             0
# price                           0
# freight_value                   0
# payment_sequential              3
# payment_type                    3
# payment_installments            3
# payment_value                   3
# review_id                       0
# review_score                    0
# review_comment_title       104229
# review_comment_message      67650
# review_creation_date            0
# review_answer_timestamp         0
# dtype: int64

# %%
df6=pd.read_csv("olist_orders_dataset.csv")
df6 = reduce_mem_usage(df6)
df6
# Out:
# ...
# Mem. usage decreased to  6.07 Mb (0.0% reduction)
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
# ...

# %%
df6.info()
# Out:
# <class 'modin.pandas.dataframe.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  -----------------------------  --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1 MB
# ...

# %%
df6.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
#merging csv3_4_5 and csv6
df3_4_5_6= df3_4_5.merge(df6, on='order_id', how='left')
df3_4_5_6
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 118313  fffc94f6ce00a00581880bf54a75a037              1
# 118314  fffcd46ef2263f404302a634eb57f7eb              1
# 118315  fffce4705a9662cd70adb13d4a31832d              1
# 118316  fffe18544ffabc95dfada21779c9644f              1
# 118317  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
df3_4_5_6.isnull().sum()
# Out:
# order_id                              0
# order_item_id                         0
# product_id                            0
# seller_id                             0
# shipping_limit_date                   0
# price                                 0
# freight_value                         0
# payment_sequential                    3
# payment_type                          3
# payment_installments                  3
# payment_value                         3
# review_id                             0
# review_score                          0
# review_comment_title             104229
# review_comment_message            67650
# review_creation_date                  0
# review_answer_timestamp               0
# customer_id                           0
# order_status                          0
# order_purchase_timestamp              0
# order_approved_at                    15
# order_delivered_carrier_date       1254
# order_delivered_customer_date      2588
# ...

# %%
df7=pd.read_csv("olist_products_dataset.csv")
df7 = reduce_mem_usage(df7)
df7
# Out:
# ...
# Mem. usage decreased to  0.94 Mb (58.3% reduction)
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...

# %%
df7.info()
# Out:
# ...
# <class 'modin.pandas.dataframe.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  --------------------------  --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float16
#  3   product_description_lenght  32341 non-null  float16
#  4   product_photos_qty          32341 non-null  float16
#  5   product_weight_g            32949 non-null  float16
#  6   product_length_cm           32949 non-null  float16
#  7   product_height_cm           32949 non-null  float16
#  8   product_width_cm            32949 non-null  float16
# dtypes: float16(7), object(2)
# memory usage: 965.5 KB

# %%
df7.isnull().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
#Merging csv3_4_5_6 and csv 7
df3_4_5_6_7= df3_4_5_6.merge(df7, on='product_id', how='left')
df3_4_5_6_7
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 118313  fffc94f6ce00a00581880bf54a75a037              1
# 118314  fffcd46ef2263f404302a634eb57f7eb              1
# 118315  fffce4705a9662cd70adb13d4a31832d              1
# 118316  fffe18544ffabc95dfada21779c9644f              1
# 118317  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
df3_4_5_6_7.isnull().sum()
# Out:
# order_id                              0
# order_item_id                         0
# product_id                            0
# seller_id                             0
# shipping_limit_date                   0
# price                                 0
# freight_value                         0
# payment_sequential                    3
# payment_type                          3
# payment_installments                  3
# payment_value                         3
# review_id                             0
# review_score                          0
# review_comment_title             104229
# review_comment_message            67650
# review_creation_date                  0
# review_answer_timestamp               0
# customer_id                           0
# order_status                          0
# order_purchase_timestamp              0
# order_approved_at                    15
# order_delivered_carrier_date       1254
# order_delivered_customer_date      2588
# ...

# %%
df8=pd.read_csv("olist_sellers_dataset.csv")
df8 = reduce_mem_usage(df8)
df8
# Out:
# ...
# Mem. usage decreased to  0.08 Mb (12.5% reduction)
#                              seller_id  seller_zip_code_prefix  \
# 0     3442f8959a84dea7ee197c632cb2df15                   13023
# 1     d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2     ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3     c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4     51a04a8a6bdcb23deccc82b0b80742cf                   12914
# ...                                ...                     ...
# 3090  98dddbc4601dd4443ca174359b237166                   87111
# 3091  f8201cab383e484733266d1906e2fdfa                   88137
# 3092  74871d19219c7d518d0090283e03c137                    4650
# 3093  e603cf3fec55f8697c9059638d6c8eb5                   96080
# 3094  9e25199f6ef7e7c347120ff175652c3b                   12051
#
#             seller_city seller_state
# 0              campinas           SP
# 1            mogi guacu           SP
# 2        rio de janeiro           RJ
# ...

# %%
df8.info()
# Out:
# <class 'modin.pandas.dataframe.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ----------------------  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int32
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: object(3), int32(1)
# memory usage: 84.8 KB
# ...

# %%
df8.isnull().sum()
# Out:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %%
#Merging csv3_4_5_6_7 and csv 8
df3_4_5_6_7_8= df3_4_5_6_7.merge(df8, on='seller_id', how='left')
df3_4_5_6_7_8
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 118313  fffc94f6ce00a00581880bf54a75a037              1
# 118314  fffcd46ef2263f404302a634eb57f7eb              1
# 118315  fffce4705a9662cd70adb13d4a31832d              1
# 118316  fffe18544ffabc95dfada21779c9644f              1
# 118317  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
df3_4_5_6_7_8.isnull().sum()
# Out:
# order_id                              0
# order_item_id                         0
# product_id                            0
# seller_id                             0
# shipping_limit_date                   0
# price                                 0
# freight_value                         0
# payment_sequential                    3
# payment_type                          3
# payment_installments                  3
# payment_value                         3
# review_id                             0
# review_score                          0
# review_comment_title             104229
# review_comment_message            67650
# review_creation_date                  0
# review_answer_timestamp               0
# customer_id                           0
# order_status                          0
# order_purchase_timestamp              0
# order_approved_at                    15
# order_delivered_carrier_date       1254
# order_delivered_customer_date      2588
# ...

# %%
df9=pd.read_csv("product_category_name_translation.csv")
df9 = reduce_mem_usage(df9)
df9
# Out:
# ...
# Mem. usage decreased to  0.00 Mb (0.0% reduction)
#             product_category_name product_category_name_english
# 0                    beleza_saude                 health_beauty
# 1          informatica_acessorios         computers_accessories
# 2                      automotivo                          auto
# 3                 cama_mesa_banho                bed_bath_table
# 4                moveis_decoracao               furniture_decor
# ..                            ...                           ...
# 66                         flores                       flowers
# 67             artes_e_artesanato         arts_and_craftmanship
# 68                fraldas_higiene           diapers_and_hygiene
# 69  fashion_roupa_infanto_juvenil     fashion_childrens_clothes
# 70             seguros_e_servicos         security_and_services
#
# [71 rows x 2 columns]

# %%
df9.info()
# Out:
# <class 'modin.pandas.dataframe.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  -----------------------------  --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2 KB
# ...

# %%
df9.isnull().sum()
# Out:
# product_category_name            0
# product_category_name_english    0
# dtype: int64

# %%
#Merging csv3_4_5_6_7_8 and csv 9
df3_4_5_6_7_8_9= df3_4_5_6_7_8.merge(df9, on='product_category_name', how='left')
df3_4_5_6_7_8_9
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 118313  fffc94f6ce00a00581880bf54a75a037              1
# 118314  fffcd46ef2263f404302a634eb57f7eb              1
# 118315  fffce4705a9662cd70adb13d4a31832d              1
# 118316  fffe18544ffabc95dfada21779c9644f              1
# 118317  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
df3_4_5_6_7_8_9.isnull().sum()
# Out:
# order_id                              0
# order_item_id                         0
# product_id                            0
# seller_id                             0
# shipping_limit_date                   0
# price                                 0
# freight_value                         0
# payment_sequential                    3
# payment_type                          3
# payment_installments                  3
# payment_value                         3
# review_id                             0
# review_score                          0
# review_comment_title             104229
# review_comment_message            67650
# review_creation_date                  0
# review_answer_timestamp               0
# customer_id                           0
# order_status                          0
# order_purchase_timestamp              0
# order_approved_at                    15
# order_delivered_carrier_date       1254
# order_delivered_customer_date      2588
# ...

# %%
#Merging csv3_4_5_6_7_8_9 and csv 1
df3_4_5_6_7_8_9_1= df3_4_5_6_7_8_9.merge(df1, on='customer_id', how='left')
df3_4_5_6_7_8_9_1
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 118313  fffc94f6ce00a00581880bf54a75a037              1
# 118314  fffcd46ef2263f404302a634eb57f7eb              1
# 118315  fffce4705a9662cd70adb13d4a31832d              1
# 118316  fffe18544ffabc95dfada21779c9644f              1
# 118317  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
df3_4_5_6_7_8_9_1.isnull().sum()
# Out:
# order_id                              0
# order_item_id                         0
# product_id                            0
# seller_id                             0
# shipping_limit_date                   0
# price                                 0
# freight_value                         0
# payment_sequential                    3
# payment_type                          3
# payment_installments                  3
# payment_value                         3
# review_id                             0
# review_score                          0
# review_comment_title             104229
# review_comment_message            67650
# review_creation_date                  0
# review_answer_timestamp               0
# customer_id                           0
# order_status                          0
# order_purchase_timestamp              0
# order_approved_at                    15
# order_delivered_carrier_date       1254
# order_delivered_customer_date      2588
# ...

# %%
df3_4_5_6_7_8_9_1.shape
# Out:
# (118318, 40)

# %%
#Convering merge data into csv
df.to_csv('df3_4_5_6_7_8_9_1')
